# %% [markdown]
# ### This script converts the Excel report exported from xPortal2005 fingerprint scanning machine into tidy data for payroll purposes

# %%
import pandas as pd

# %%
df = pd.concat(pd.read_excel('Attendance report.xls', sheet_name=None, skiprows=3)).reset_index()
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.head()
# Out:
#   level_0  level_1         Day        Date  Unnamed: 2  \
# 0  Sheet1        0         NaN         NaN         NaN
# 1  Sheet1        1         NaN         NaN         NaN
# 2  Sheet1        2  Wednesday   2019/08/28         NaN
# 3  Sheet1        3         NaN         NaN         NaN
# 4  Sheet1        4  Wednesday   2019/08/28         NaN
#
#                      CardNo Unnamed: 4  Unnamed: 5  Unnamed: 6 Unnamed: 7  \
# 0  Work-Recorded / Ammended        NaN         NaN         NaN        NaN
# 1                       NaN         IN         NaN         NaN        OUT
# 2                         4        NaN         NaN         NaN        NaN
# 3                       NaN   00:00            NaN         NaN   00:00
# 4                        35        NaN         NaN         NaN        NaN
#
#    ...  Dept                                        Unnamed: 32 Div  \
# 0  ...   NaN                                            Summary NaN
# 1  ...   NaN                                                NaN NaN
# 2  ...   NaN                                          Managemen NaN
# 3  ...   NaN  Absent                                        ... NaN
# 4  ...   NaN                                          Managemen NaN
#
#        Unnamed: 34 Unnamed: 35        Job Title Unnamed: 37 Unnamed: 38  \
# 0              NaN         NaN              NaN         NaN         NaN
# 1              NaN         NaN              NaN         NaN         NaN
# 2  N/Available             NaN  Executive               NaN         NaN
# 3              NaN         NaN              NaN         NaN         NaN
# 4  N/Available             NaN  Executive               NaN         NaN
#
#   Unnamed: 39  Unnamed: 40
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Get time in, time out x 4

# %%
def get_tito_1():
    _df = df[['Unnamed: 4', 'Unnamed: 7']].dropna().reset_index(drop=True)
    return _df[~_df['Unnamed: 4'].str.contains('IN')].reset_index(drop=True).rename(columns={'Unnamed: 4': 'In (1)', 'Unnamed: 7': 'Out (1)'})

tito_1 = get_tito_1()

def get_tito_2():
    _df = df[['Staff No', 'Unnamed: 12']].dropna().reset_index(drop=True)
    return _df[~_df['Staff No'].str.contains('IN')].reset_index(drop=True).rename(columns={'Staff No': 'In (2)', 'Unnamed: 12': 'Out (2)'})

tito_2 = get_tito_2()

def get_tito_3():
    _df = df[['Unnamed: 15', 'Unnamed: 18']].dropna().reset_index(drop=True)
    return _df[~_df['Unnamed: 15'].str.contains('OUT')].reset_index(drop=True).rename(columns={'Unnamed: 15': 'Out (3)', 'Unnamed: 18': 'In (3)'})

tito_3 = get_tito_3()

def get_tito_4():
    _df = df[['Unnamed: 20', 'Unnamed: 22']].dropna().reset_index(drop=True)
    return _df[~_df['Unnamed: 20'].str.contains('OUT')].reset_index(drop=True).rename(columns={'Unnamed: 20': 'Out (4)', 'Unnamed: 22': 'In (4)'})

tito_4 = get_tito_4()

# %% [markdown]
# ### Get the rest of the columns

# %%
def get_staff_no():
    _df = df[['Staff No']].dropna().reset_index(drop=True)
    return _df[_df['Staff No'].str.contains('JL')].reset_index(drop=True)

staff_no = get_staff_no()

def get_total():
    _df = df[['Unnamed: 24']].dropna().rename(columns={'Unnamed: 24': 'Total'})
    _df = _df[~_df['Total'].str.contains('Total')]
    return _df[~_df['Total'].str.contains('Work Hour')].reset_index(drop=True)

total = get_total()

def get_branch_normal():
    _df = df[['Branch']].dropna()
    _df = _df[~_df['Branch'].str.contains('Normal')].reset_index(drop=True)
    return _df.iloc[0::2].reset_index(drop=True), _df.iloc[1::2].reset_index(drop=True).rename(columns={'Branch': 'Normal'})

branch, normal = get_branch_normal()

def get_ot():
    _df = df[['Unnamed: 29']].dropna().reset_index(drop=True)
    return _df[~_df['Unnamed: 29'].str.contains('OT')].reset_index(drop=True).rename(columns={'Unnamed: 29': 'OT'})

ot = get_ot()

def get_division_summary():
    _df = df[['Unnamed: 32']].dropna().reset_index(drop=True)
    _df = _df[~_df['Unnamed: 32'].str.contains('Summary')].reset_index(drop=True)
    return _df.iloc[0::2].reset_index(drop=True).rename(columns={'Unnamed: 32': 'Department'}), _df.iloc[1::2].reset_index(drop=True).rename(columns={'Unnamed: 32': 'Summary'})

division, summary = get_division_summary()

# %%
day_date_cardno = df[['Day', 'Date', 'CardNo']].dropna().reset_index(drop=True)
staff_name = df[['Staff Name']].dropna().reset_index(drop=True)
status = df[['Unnamed: 34']].dropna().reset_index(drop=True).rename(columns={'Unnamed: 34': 'Status'})
job_title = df[['Job Title']].dropna().reset_index(drop=True)

# %% [markdown]
# ### Concat into final df, clean strings and groupby for export into csv files

# %%
final_df = pd.concat([day_date_cardno, staff_no, staff_name, division, job_title, branch, normal, summary, status, 
           tito_1, tito_2, tito_3, tito_4, total, ot], axis=1)

# %%
# Strip away white space and remove / character (for exporting to CSV)
final_df['Staff Name'] = final_df['Staff Name'].str.strip().str.replace('/', '')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
final_df
# Out:
#             Day        Date CardNo         Staff No  \
# 0    Wednesday   2019/08/28  4      JL004
# 1    Wednesday   2019/08/28  35     JL035
# 2    Wednesday   2019/08/28  20     JL020
# 3    Wednesday   2019/08/28  40     JL040
# 4    Wednesday   2019/08/28  29     JL029
# ..          ...         ...  ..                 ...
# 575  Wednesday   2019/09/25  6      JL006
# 576  Wednesday   2019/09/25  13     JL013
# 577  Wednesday   2019/09/25  3      JL003
# 578  Wednesday   2019/09/25  9      JL009
# 579  Wednesday   2019/09/25  11     JL011
#
#                                 Staff Name       Department        Job Title  \
# 0    R.Thiagarajan AL S.Ramasamy            Managemen        Executive
# 1    Muhammad Fikrie Hadi Bin Samson Azhar  Managemen        Executive
# 2    Muhd Rasyid Bin Asiab                  Managemen        N/Available
# 3    YUSOF                                  Managemen        Executive
# 4    Sanawiah                               Admin            G.Clerk
# ..        ...                                           ...              ...
# 575  Tham Pek Fah                           Managemen        Executive
# 576  Mohd Zulkifli Hilmi Bin Abd Rahman     Managemen        G.Clerk
# 577  Sugunna AP Subramaniam                 Admin            G.Clerk
# 578  Teo Gek Cheng                          Managemen        Executive
# 579  Azni Bin Hashim                        Managemen        Executive
#
#               Branch  Normal  \
# 0    HQ               00:00
# 1    HQ               00:00
# 2    HQ               07:32
# 3    HQ               07:41
# 4    HQ               07:34
# ..               ...     ...
# 575  HQ               07:44
# 576  HQ               07:51
# 577  HQ               07:49
# 578  HQ               07:21
# 579  HQ               07:09
#
#                                                                                                   Summary  \
# 0    Absent
# 1    Absent
# 2    EarlyIn+EarlyOut
# 3    EarlyIn+EarlyOut+EarlyInFromLunch+InCompleteLunch
# 4    EarlyIn+EarlyOut
# ..                                                                                                    ...
# 575  EarlyIn+EarlyOut
# 576  LateIn+LateOut
# 577  LateIn+LateOut
# 578  LateIn+LateOut
# 579  LateIn+LateOut
#
#      ...    In (1)   Out (1)    In (2)   Out (2)     Out (3)      In (3)  \
# 0    ...  00:00     00:00     00:00     00:00     00:00       00:00
# 1    ...  00:00     00:00     00:00     00:00     00:00       00:00
# 2    ...  06:48     17:02     00:00     00:00     00:00       00:00
# 3    ...  06:51     17:11     00:00     00:00     00:00       13:04
# 4    ...  07:28     17:04     00:00     00:00     00:00       00:00
# ..   ...       ...       ...       ...       ...         ...         ...
# 575  ...  08:05     17:14     00:00     00:00     00:00       00:00
# 576  ...  08:39     18:02     00:00     00:00     00:00       00:00
# 577  ...  08:41     18:04     00:00     00:00     00:00       00:00
# 578  ...  09:09     18:05     00:00     00:00     00:00       00:00
# 579  ...  09:21     18:05     00:00     00:00     00:00       00:00
#
#       Out (4)    In (4)   Total      OT
# 0    00:00     00:00     00:00   00:00
# 1    00:00     00:00     00:00   00:00
# 2    00:00     00:00     07:32   00:00
# 3    00:00     00:00     07:41   00:00
# 4    00:00     00:00     07:34   00:00
# ..        ...       ...     ...     ...
# 575  00:00     00:00     07:44   00:00
# 576  00:00     00:00     08:23   00:00
# 577  00:00     00:00     08:23   00:00
# 578  00:00     00:00     07:56   00:00
# 579  00:00     00:00     07:44   00:00
#
# [580 rows x 21 columns]

# %%
# Group by staff name and generate csv files 
grouped = final_df.groupby('Staff Name')

for i, (staff_name, data) in enumerate(grouped, 1):
    data.to_csv(f"{i}_{staff_name}.csv")
